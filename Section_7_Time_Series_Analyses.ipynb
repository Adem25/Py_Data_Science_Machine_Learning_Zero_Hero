# %%
import yfinance as yf
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
df = yf.download('AAPL', start='2022-01-01', end='2022-02-15')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.724579
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.443542
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.723587
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  169.840256
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.008148
# 2022-01-10  169.080002  172.500000  168.169998  172.190002  170.027863
# 2022-01-11  172.320007  175.179993  170.820007  175.080002  172.881561
# 2022-01-12  176.119995  177.179993  174.820007  175.529999  173.325928
# 2022-01-13  175.779999  176.619995  171.789993  172.190002  170.027863
# 2022-01-14  171.339996  173.779999  171.089996  173.070007  170.896835
# 2022-01-18  171.509995  172.539993  169.410004  169.800003  167.667892
# 2022-01-19  170.000000  171.080002  165.940002  166.229996  164.142715
# ...

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.index = pd.to_datetime(df.index)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.724579
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  177.443542
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.723587
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  169.840256
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.008148
# 2022-01-10  169.080002  172.500000  168.169998  172.190002  170.027863
# 2022-01-11  172.320007  175.179993  170.820007  175.080002  172.881561
# 2022-01-12  176.119995  177.179993  174.820007  175.529999  173.325928
# 2022-01-13  175.779999  176.619995  171.789993  172.190002  170.027863
# 2022-01-14  171.339996  173.779999  171.089996  173.070007  170.896835
# 2022-01-18  171.509995  172.539993  169.410004  169.800003  167.667892
# 2022-01-19  170.000000  171.080002  165.940002  166.229996  164.142715
# ...

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_eth = pd.read_csv('ETH_1h.csv', index_col='Date')
df_eth
# Out:
#                   Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...         ...
# 2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df_eth.index = pd.to_datetime(df_eth.index, format='%Y-%m-%d %I-%p') 
df_eth
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
jan1 = pd.to_datetime('2022, 1, 1')
jan1.day_name()
# Out:
# 'Saturday'

# %%
Image("ts_min_max.png")

# %%
Image("ts_datetime_range.png")

# %%
Image("ts_time_based_indexing.png")

# %%
Image("ts_time_based_indexing_slicing.png")

# %%
Image("ts_time_based_indexing_partially_macht.png")

# %%
df.loc['2022-02']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-02-01  174.009995  174.839996  172.309998  174.610001  172.417480
# 2022-02-02  174.750000  175.880005  173.330002  175.839996  173.632019
# 2022-02-03  174.479996  176.240005  172.119995  172.899994  170.728928
# 2022-02-04  171.679993  174.100006  170.679993  172.389999  170.442230
# 2022-02-07  172.860001  173.949997  170.949997  171.660004  169.720490
# 2022-02-08  171.729996  175.350006  171.429993  174.830002  172.854660
# 2022-02-09  176.050003  176.649994  174.899994  176.279999  174.288284
# 2022-02-10  174.139999  175.479996  171.550003  172.119995  170.175278
# 2022-02-11  172.330002  173.080002  168.039993  168.639999  166.734604
# 2022-02-14  167.369995  169.580002  166.559998  168.880005  166.971924
#
#               Volume
# Date
# 2022-02-01  86213900
# 2022-02-02  84914300
# 2022-02-03  89418100
# 2022-02-04  82465400
# 2022-02-07  77251200
# 2022-02-08  74829200
# ...

# %%
df = yf.download('AAPL', start='2017-01-01', end='2021-12-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.figure(figsize=(15, 5))
plt.title('Apple Stock Prices for 5 years')
plt.xlabel('Year')
plt.ylabel('Price')

plt.plot(df['Adj Close'])

# %%
plt.figure(figsize=(15, 5))
plt.title('Apple Stock Prices for 2021')
plt.xlabel('Year')
plt.ylabel('Price')

plt.plot(df.loc['2021']['Adj Close'])
