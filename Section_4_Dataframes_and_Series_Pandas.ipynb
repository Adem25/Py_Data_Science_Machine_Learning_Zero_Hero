# %%
import pandas as pd
import numpy as np

# %%
myList =  [['Apple','Red'],['Banana', 'Yellow'], ['Organe','Orange']]

# %%
myDataFrame = pd.DataFrame(myList, columns=['Fruit', 'Color'])
myDataFrame
# Out:
#     Fruit   Color
# 0   Apple     Red
# 1  Banana  Yellow
# 2  Organe  Orange

# %%
myNpList = np.array([[0,1],[2,3],[4,5]])

# %%
myNpDataFrame = pd.DataFrame(myNpList, columns=['even', 'odd'])
myNpDataFrame
# Out:
#    even  odd
# 0     0    1
# 1     2    3
# 2     4    5

# %%
myDictionary = {'Fruit':['Apple', 'Banana', 'Organe'], 'Color':['Red', 'Yellow', 'Orange']}

# %%
myDictionaryDataFrame = pd.DataFrame(myDictionary)
myDictionaryDataFrame
# Out:
#     Fruit   Color
# 0   Apple     Red
# 1  Banana  Yellow
# 2  Organe  Orange

# %%
df = pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name')
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df # functions do not change the df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
#df.set_index('name', inplace=True)
#df # now it will change df

# %%
df.head(5) # first 5
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.tail(5) #last 5
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df[['name','rating']]
# Out:
#                         name     rating
# 0                  100% Bran  68.402973
# 1          100% Natural Bran  33.983679
# 2                   All-Bran  59.425505
# 3  All-Bran with Extra Fiber  93.704912
# 4             Almond Delight  34.384843
# 5    Apple Cinnamon Cheerios  29.509541
# 6                Apple Jacks  33.174094
# 7                    Basic 4  37.038562
# 8                  Bran Chex  49.120253
# 9                Bran Flakes  53.313813

# %%
dfFirstFive = df[0:5]
thirdRow = [False, False, True, False, False]
dfFirstFive[thirdRow]
# Out:
#        name  calories  protein  vitamins     rating
# 2  All-Bran        70        4        25  59.425505

# %%
conditon = df['calories'] > 70
df[conditon]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories'] > 70) & (df['protein'] < 4)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories'] > 70) | (df['protein'] > 3)]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.loc[0, 'name']
# Out:
# '100% Bran'

# %%
df.loc[[0],['name']]
# Out:
#         name
# 0  100% Bran

# %%
df.loc[0:4, 'name':'protein']
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.loc[[5,8],'name':'protein']
# Out:
#                       name  calories  protein
# 5  Apple Cinnamon Cheerios       110        2
# 8                Bran Chex        90        2

# %%
df.iloc[9,2]
# Out:
# 3

# %%
df.iloc[[9],[2]]
# Out:
#    protein
# 9        3

# %%
df.iloc[0:5, 0:3]
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[[0,2,4], 0:3]
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %%
dfFirstFive.loc[6] = ['Trix', 110, 1, 25, 27.765]
dfFirstFive
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 6                       Trix       110        1        25  27.765000

# %%
dfFirstFive.drop(6,axis=0, inplace=True)
dfFirstFive
# Out:
# C:\Users\Adem_\AppData\Local\Temp\ipykernel_18312\1940706190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFirstFive.drop(6,axis=0, inplace=True)
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
dfFirstFive['MyColumn'] = ['A', 'B', 'C', 'C', 'D']
dfFirstFive
# Out:
# C:\Users\Adem_\AppData\Local\Temp\ipykernel_18312\1604558136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFirstFive['MyColumn'] = ['A', 'B', 'C', 'C', 'D']
#                         name  calories  protein  vitamins     rating MyColumn
# 0                  100% Bran        70        4        25  68.402973        A
# 1          100% Natural Bran       120        3         0  33.983679        B
# 2                   All-Bran        70        4        25  59.425505        C
# 3  All-Bran with Extra Fiber        50        4        25  93.704912        C
# 4             Almond Delight       110        2        25  34.384843        D

# %%
dfFirstFive.drop('MyColumn', axis=1, inplace=True)
dfFirstFive
# Out:
# C:\Users\Adem_\AppData\Local\Temp\ipykernel_18312\3512877083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFirstFive.drop('MyColumn', axis=1, inplace=True)
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.sort_values(by='calories')
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
df.sort_values(by='calories', ascending=False)
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
dfFirstFive.to_csv('MyFile.csv', index_label=False)

# %%
newDf = pd.read_csv('MyFile.csv')
newDf
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df1 = df[0:3]
df2 = df[5:8]
df2 = df2.reset_index(drop=True)

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                 name  calories  protein  vitamins     rating  \
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
#
#                       name  calories  protein  vitamins     rating
# 0  Apple Cinnamon Cheerios       110        2        25  29.509541
# 1              Apple Jacks       110        2        25  33.174094
# 2                  Basic 4       130        3        25  37.038562

# %%
data = {'Gender': ['female', 'male','female', 'male'], 'Score': [85, 88, 95,80]}
dfDict = pd.DataFrame.from_dict(data)
dfDict
# Out:
#    Gender  Score
# 0  female     85
# 1    male     88
# 2  female     95
# 3    male     80

# %%
dfDict.groupby(dfDict['Gender']).mean()
# Out:
#         Score
# Gender
# female   90.0
# male     84.0
